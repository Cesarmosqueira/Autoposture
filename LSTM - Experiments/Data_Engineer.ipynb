# %% [markdown]
# # Data Engineer: Fine-tuning the dataset

# %% [markdown]
# ### Correct way of sitting:

# %% [markdown]
# ![](https://ssep.com.au/wp-content/uploads/2021/05/best-posture-for-sitting-at-a-desk-all-day.jpg)

# %% [markdown]
# ### YoloV7 keypoint layout:

# %% [markdown]
# ![Exploring output keypoints](https://miro.medium.com/v2/resize:fit:720/format:webp/1*PM5Q-58eNOWdoLogVKCGnQ.png)

# %% [markdown]
# ### Ideas for making dataset better
# Adding columns to dataset with data:
# *   Adding the angles between arm and forarm (90 - 120 degrees)
# *   Shoulders (landmarks 5 and 6) allign (with some margin)
# *   Elbows wider than shoulders (not too wider)
# *   If legs are marked -> 80-90 degrees from torso
#
# \
# Deleting some rows if:
# *   Less than # landmarks are not displayed (we can say which specifics)
